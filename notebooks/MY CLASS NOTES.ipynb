# %%
reload_lamb()
#from lamb.types import TypeMismatch, type_e, type_t, type_property
#from lamb.meta import TypedTerm, TypedExpr, LFun, CustomTerm
from IPython.display import display

# %%
# Just some basic configuration
meta.constants_use_custom(False)
lang.bracket_setting = lang.BRACKET_FANCY
lamb.display.default(style=lamb.display.DerivStyle.BOXES) # you can also try lamb.display.DerivStyle.PROOF

# %% [markdown]
# # Scratchpad section
#
# See later sections for 2019, 2021 exams etc.

# %%
# %%lamb
# ||every|| = λ f_<e,t> : λ g_<e,t> : Forall x_e : f(x) >> g(x)
# ||student|| = L x_e : Student(x)
# ||danced|| = L x_e : Danced(x)
# Out:
# INFO (meta): Coerced guessed type for 'Student_t' into <e,t>, to match argument 'x_e'
# INFO (meta): Coerced guessed type for 'Danced_t' into <e,t>, to match argument 'x_e'
# $[\![\mathbf{\text{every}}]\!]^{}_{\left\langle{}\left\langle{}e,t\right\rangle{},\left\langle{}\left\langle{}e,t\right\rangle{},t\right\rangle{}\right\rangle{}} \:=\: $$\lambda{} f_{\left\langle{}e,t\right\rangle{}} \: . \: \lambda{} g_{\left\langle{}e,t\right\rangle{}} \: . \: \forall{} x_{e} \: . \: ({f}({x}) \rightarrow{} {g}({x}))$<br />
# $[\![\mathbf{\text{student}}]\!]^{}_{\left\langle{}e,t\right\rangle{}} \:=\: $$\lambda{} x_{e} \: . \: {Student}({x})$<br />
# $[\![\mathbf{\text{danced}}]\!]^{}_{\left\langle{}e,t\right\rangle{}} \:=\: $$\lambda{} x_{e} \: . \: {Danced}({x})$

# %%
r = ((every * student) * danced)
r
# Out:
# CompositionResult(results=[⟦[[every student] danced]⟧ = (Forall x_e: (Student_<e,t>(x_e) >> Danced_<e,t>(x_e)))], failures=[⟦[danced [every student]]⟧ = Type mismatch: '⟦danced⟧ = (λ x_e: Danced_<e,t>(x_e))'/<e,t> and '⟦[every student]⟧ = (λ g_<e,t>: (Forall x_e: (Student_<e,t>(x_e) >> g_<e,t>(x_e))))'/<<e,t>,t> conflict (Function Application), ⟦[[every student] danced]⟧ = Type mismatch: '⟦[every student]⟧ = (λ g_<e,t>: (Forall x_e: (Student_<e,t>(x_e) >> g_<e,t>(x_e))))'/<<e,t>,t> and '⟦danced⟧ = (λ x_e: Danced_<e,t>(x_e))'/<e,t> conflict (Predicate Modification), ⟦[[every student] danced]⟧ = Composition failure (PA requires a valid binder) on: ⟦[every student]⟧ = (λ g_<e,t>: (Forall x_e: (Student_<e,t>(x_e) >> g_<e,t>(x_e)))) * ⟦danced⟧ = (λ x_e: Danced_<e,t>(x_e)), ⟦[danced [every student]]⟧ = Composition failure (PA requires a valid binder) on: ⟦danced⟧ = (λ x_e: Danced_<e,t>(x_e)) * ⟦[every student]⟧ = (λ g_<e,t>: (Forall x_e: (Student_<e,t>(x_e) >> g_<e,t>(x_e)))), ⟦[[every stu
# ...

# %%
r.tree()
# Out:
# 1 composition path:<br /><div align="center" style="display:table; margin:5px; border-collapse: collapse;border: 1px solid #848482;"><div align="center" style="display:table-row;border-bottom:1px solid #848482"><div style="display:table-cell;vertical-align:middle;"><div style="display: table;"><div style="display:table-cell;vertical-align:middle;padding-left:5px;padding-right:5px;padding-top:5px;padding-bottom:5px;"><div align="center" style="display:table; margin:5px; border-collapse: collapse;border: 1px solid #848482;"><div align="center" style="display:table-row;border-bottom:1px solid #848482"><div style="display:table-cell;vertical-align:middle;"><div style="display: table;"><div style="display:table-cell;vertical-align:middle;padding-left:5px;padding-right:5px;padding-top:5px;padding-bottom:5px;"><div align="center" style="display:block;padding-left:5px;padding-right:5px;padding-top:5px;padding-bottom:5px;"><div style="display:table;table-layout:auto;" align="center"><div styl
# ...

# %%
# %%lamb
# #||every|| = λ f_<e,t> : λ g_<e,t> : Forall x_e : f(x) >> g(x)
# #||student|| = L x_e : Student(x)
# #||danced|| = L x_e : Danced(x)
#
# # Sentence: 'Every man who loves Rebecca loves a woman.'
#
#
# ||woman|| = L x_e : Woman(x)
# ||a|| = L n_<e,t> : L m_<e,t> : Exists x_e : n(x) & m(x)
#
#
# ||every|| = λ n_<e,t> : λ m_<e,t> : Forall x : n(x) >> m(x)
# Out:
# INFO (meta): Coerced guessed type for 'Woman_t' into <e,t>, to match argument 'x_e'
# $[\![\mathbf{\text{woman}}]\!]^{}_{\left\langle{}e,t\right\rangle{}} \:=\: $$\lambda{} x_{e} \: . \: {Woman}({x})$<br />
# $[\![\mathbf{\text{a}}]\!]^{}_{\left\langle{}\left\langle{}e,t\right\rangle{},\left\langle{}\left\langle{}e,t\right\rangle{},t\right\rangle{}\right\rangle{}} \:=\: $$\lambda{} n_{\left\langle{}e,t\right\rangle{}} \: . \: \lambda{} m_{\left\langle{}e,t\right\rangle{}} \: . \: \exists{} x_{e} \: . \: ({n}({x}) \wedge{} {m}({x}))$<br />
# $[\![\mathbf{\text{every}}]\!]^{}_{\left\langle{}\left\langle{}e,t\right\rangle{},\left\langle{}\left\langle{}e,t\right\rangle{},t\right\rangle{}\right\rangle{}} \:=\: $$\lambda{} n_{\left\langle{}e,t\right\rangle{}} \: . \: \lambda{} m_{\left\langle{}e,t\right\rangle{}} \: . \: \forall{} x_{e} \: . \: ({n}({x}) \rightarrow{} {m}({x}))$

# %%
#r = ((every * student) * danced)
#r

# %%
bla = (a * woman)
bla
bla.tree()
# Out:
# 1 composition path:<br /><div align="center" style="display:table; margin:5px; border-collapse: collapse;border: 1px solid #848482;"><div align="center" style="display:table-row;border-bottom:1px solid #848482"><div style="display:table-cell;vertical-align:middle;"><div style="display: table;"><div style="display:table-cell;vertical-align:middle;padding-left:5px;padding-right:5px;padding-top:5px;padding-bottom:5px;"><div align="center" style="display:block;padding-left:5px;padding-right:5px;padding-top:5px;padding-bottom:5px;"><div style="display:table;table-layout:auto;" align="center"><div style="display:table-row;"><div style="display:table-cell;padding-right:2px; padding-left:2px;" align="center"><div style="display:inline-block;"><span>$[\![\mathbf{\text{a}}]\!]^{}_{\left\langle{}\left\langle{}e,t\right\rangle{},\left\langle{}\left\langle{}e,t\right\rangle{},t\right\rangle{}\right\rangle{}}$</span></div></div></div><div style="display:table-row;"><div style="display:table-cell;p
# ...

# %% [markdown]
# eric NP
#
# rebecca NP
#
# everybody NP
#
# somebody NP
#
# man N
#
# woman N
#
# every N → NP
#
# a N → NP
#
# loves NP → NP → S
#
# who(NP → S) → N → N
#
#
# [[N]] = e → t
#
# [[NP]] = (e → t) → t
#
# [[S]] = t

# %%
# %%lamb
# ||man|| = L x_e : Man(x)
# ||woman|| = L x_e : Woman(x)
# ||every|| = λ n_<e,t> : λ m_<e,t> : Forall x : n(x) >> m(x)
# ||a|| = L n_<e,t> : L m_<e,t> : Exists x_e : n(x) & m(x)
# # o for object, s for subject
# ||loves|| = L o_<<e,t>,t>: L s_<<e,t>,t>: s(L x_e: o(L y_e: Love(x,y)))
# Out:
# INFO (meta): Coerced guessed type for 'Man_t' into <e,t>, to match argument 'x_e'
# INFO (meta): Coerced guessed type for 'Woman_t' into <e,t>, to match argument 'x_e'
# INFO (meta): Coerced guessed type for 'Love_t' into <(e,e),t>, to match argument '(x_e, y_e)'
# $[\![\mathbf{\text{man}}]\!]^{}_{\left\langle{}e,t\right\rangle{}} \:=\: $$\lambda{} x_{e} \: . \: {Man}({x})$<br />
# $[\![\mathbf{\text{woman}}]\!]^{}_{\left\langle{}e,t\right\rangle{}} \:=\: $$\lambda{} x_{e} \: . \: {Woman}({x})$<br />
# $[\![\mathbf{\text{every}}]\!]^{}_{\left\langle{}\left\langle{}e,t\right\rangle{},\left\langle{}\left\langle{}e,t\right\rangle{},t\right\rangle{}\right\rangle{}} \:=\: $$\lambda{} n_{\left\langle{}e,t\right\rangle{}} \: . \: \lambda{} m_{\left\langle{}e,t\right\rangle{}} \: . \: \forall{} x_{e} \: . \: ({n}({x}) \rightarrow{} {m}({x}))$<br />
# ...

# %%
S_every_man = (every*man)
S_every_man.trace()
S_every_man.tree()
# Out:
# 1 composition path:<br /><div align="center" style="display:table; margin:5px; border-collapse: collapse;border: 1px solid #848482;"><div align="center" style="display:table-row;border-bottom:1px solid #848482"><div style="display:table-cell;vertical-align:middle;"><div style="display: table;"><div style="display:table-cell;vertical-align:middle;padding-left:5px;padding-right:5px;padding-top:5px;padding-bottom:5px;"><div align="center" style="display:block;padding-left:5px;padding-right:5px;padding-top:5px;padding-bottom:5px;"><div style="display:table;table-layout:auto;" align="center"><div style="display:table-row;"><div style="display:table-cell;padding-right:2px; padding-left:2px;" align="center"><div style="display:inline-block;"><span>$[\![\mathbf{\text{every}}]\!]^{}_{\left\langle{}\left\langle{}e,t\right\rangle{},\left\langle{}\left\langle{}e,t\right\rangle{},t\right\rangle{}\right\rangle{}}$</span></div></div></div><div style="display:table-row;"><div style="display:table-ce
# ...

# %%
# %%lamb
# # Many thanks to Maxime for a lot of these definitions.
# ||eric|| = λ k_<e,t>: k(e)
# ||rebecca|| = λ k_<e,t>: k(r)
# ||love|| = λ o_<<e,t>,t>: λ s_<<e,t>,t>: s(λ x_e: o(λ y_e: love_<e,<e,t>>(x)(y)))
# ||everybody|| = λ k_<e,t>: Forall x_e: (human_<e,t>(x) >> k(x))
# ||somebody|| = λ k_<e,t>: Exists x_e: (human_<e,t>(x) & k(x))
# ||nobody|| = λ k_<e,t>: Forall x_e: ((human_<e,t>(x)) >> ~(k(x)))
# ||man|| = λ x_e: man_<e,t>(x)
# ||woman|| = λ x_e: woman_<e,t>(x)
# ||every|| = λ n_<e,t>: λ m_<e,t>: Forall x_e: (n(x) >> m(x))
# ||a|| = λ n_<e,t>: λ m_<e,t>: Exists x_e: (n(x) & m(x))
# ||who|| = λ r_<<<e,t>,t>,t>: λ n_<e,t>: λ x_e: n(x) & r(λ k_<e,t>: k(x))
# Out:
# $[\![\mathbf{\text{eric}}]\!]^{}_{\left\langle{}\left\langle{}e,t\right\rangle{},t\right\rangle{}} \:=\: $$\lambda{} k_{\left\langle{}e,t\right\rangle{}} \: . \: {k}({e}_{e})$<br />
# $[\![\mathbf{\text{rebecca}}]\!]^{}_{\left\langle{}\left\langle{}e,t\right\rangle{},t\right\rangle{}} \:=\: $$\lambda{} k_{\left\langle{}e,t\right\rangle{}} \: . \: {k}({r}_{e})$<br />
# $[\![\mathbf{\text{love}}]\!]^{}_{\left\langle{}\left\langle{}\left\langle{}e,t\right\rangle{},t\right\rangle{},\left\langle{}\left\langle{}\left\langle{}e,t\right\rangle{},t\right\rangle{},t\right\rangle{}\right\rangle{}} \:=\: $$\lambda{} o_{\left\langle{}\left\langle{}e,t\right\rangle{},t\right\rangle{}} \: . \: \lambda{} s_{\left\langle{}\left\langle{}e,t\right\rangle{},t\right\rangle{}} \: . \: {s}(\lambda{} x_{e} \: . \: {o}(\lambda{} y_{e} \: . \: {love}_{\left\langle{}e,\left\langle{}e,t\right\rangle{}\right\rangle{}}({x})({y})))$<br />
# ...

# %%
sent = (every * (who * (love * rebecca) * man)) * (love * (a * woman))

# %%
sent
# Out:
# CompositionResult(results=[⟦[[love [a woman]] [every [[who [love rebecca]] man]]]⟧ = (Forall x_e: ((man_<e,t>(x_e) & love_<e,<e,t>>(x_e)(r_e)) >> (Exists x1_e: (woman_<e,t>(x1_e) & love_<e,<e,t>>(x_e)(x1_e)))))], failures=[⟦[[every [[who [love rebecca]] man]] [love [a woman]]]⟧ = Type mismatch: '⟦[every [[who [love rebecca]] man]]⟧ = (λ m_<e,t>: (Forall x_e: ((man_<e,t>(x_e) & love_<e,<e,t>>(x_e)(r_e)) >> m_<e,t>(x_e))))'/<<e,t>,t> and '⟦[love [a woman]]⟧ = (λ s_<<e,t>,t>: s_<<e,t>,t>((λ x_e: (Exists x1_e: (woman_<e,t>(x1_e) & love_<e,<e,t>>(x_e)(x1_e))))))'/<<<e,t>,t>,t> conflict (Function Application), ⟦[[every [[who [love rebecca]] man]] [love [a woman]]]⟧ = Type mismatch: '⟦[every [[who [love rebecca]] man]]⟧ = (λ m_<e,t>: (Forall x_e: ((man_<e,t>(x_e) & love_<e,<e,t>>(x_e)(r_e)) >> m_<e,t>(x_e))))'/<<e,t>,t> and '⟦[love [a woman]]⟧ = (λ s_<<e,t>,t>: s_<<e,t>,t>((λ x_e: (Exists x1_e: (woman_<e,t>(x1_e) & love_<e,<e,t>>(x_e)(x1_e))))))'/<<<e,t>,t>,t> conflict (Predicate Modificati
# ...

# %%
sent.tree()
# Out:
# 1 composition path:<br /><div align="center" style="display:table; margin:5px; border-collapse: collapse;border: 1px solid #848482;"><div align="center" style="display:table-row;border-bottom:1px solid #848482"><div style="display:table-cell;vertical-align:middle;"><div style="display: table;"><div style="display:table-cell;vertical-align:middle;padding-left:5px;padding-right:5px;padding-top:5px;padding-bottom:5px;"><div align="center" style="display:table; margin:5px; border-collapse: collapse;border: 1px solid #848482;"><div align="center" style="display:table-row;border-bottom:1px solid #848482"><div style="display:table-cell;vertical-align:middle;"><div style="display: table;"><div style="display:table-cell;vertical-align:middle;padding-left:5px;padding-right:5px;padding-top:5px;padding-bottom:5px;"><div align="center" style="display:block;padding-left:5px;padding-right:5px;padding-top:5px;padding-bottom:5px;"><div style="display:table;table-layout:auto;" align="center"><div styl
# ...

# %%
# %%lamb
# # for reference: ||who|| = λ r_<<<e,t>,t>,t>: λ n_<e,t>: λ x_e: n(x) & r(λ k_<e,t>: k(x))
# ||QR|| = L n_<<e,t>,t>: L p_<<<e,t>,t>,t>:  n( L x_e: p(L k_<e,t>: k(x)) )
#
# # NOTE: I had a lot of trouble with the type annotations for the predicates inside the QR.
# # I got them to work by fiddling with them, but I don't really understand why they should be the way they are.
# Out:
# $[\![\mathbf{\text{QR}}]\!]^{}_{\left\langle{}\left\langle{}\left\langle{}e,t\right\rangle{},t\right\rangle{},\left\langle{}\left\langle{}\left\langle{}\left\langle{}e,t\right\rangle{},t\right\rangle{},t\right\rangle{},t\right\rangle{}\right\rangle{}} \:=\: $$\lambda{} n_{\left\langle{}\left\langle{}e,t\right\rangle{},t\right\rangle{}} \: . \: \lambda{} p_{\left\langle{}\left\langle{}\left\langle{}e,t\right\rangle{},t\right\rangle{},t\right\rangle{}} \: . \: {n}(\lambda{} x_{e} \: . \: {p}(\lambda{} k_{\left\langle{}e,t\right\rangle{}} \: . \: {k}({x})))$

# %%
#QR (A WOMAN) (λx. LOVE x (EVERY MAN))
# This is a wrong assignment order: QR * ( (a * woman) * (love * (every * man)) )
# This one is correct:
qrsent = ( QR * (a*woman) ) * (love*(every*man))

# %%
(love*(every*man))
# Out:
# CompositionResult(results=[⟦[love [every man]]⟧ = (λ s_<<e,t>,t>: s_<<e,t>,t>((λ x_e: (Forall x1_e: (man_<e,t>(x1_e) >> love_<e,<e,t>>(x_e)(x1_e))))))], failures=[⟦[[every man] love]⟧ = Type mismatch: '⟦[every man]⟧ = (λ m_<e,t>: (Forall x_e: (man_<e,t>(x_e) >> m_<e,t>(x_e))))'/<<e,t>,t> and '⟦love⟧ = (λ o_<<e,t>,t>: (λ s_<<e,t>,t>: s_<<e,t>,t>((λ x_e: o_<<e,t>,t>((λ y_e: love_<e,<e,t>>(x_e)(y_e)))))))'/<<<e,t>,t>,<<<e,t>,t>,t>> conflict (Function Application), ⟦[love [every man]]⟧ = Type mismatch: '⟦love⟧ = (λ o_<<e,t>,t>: (λ s_<<e,t>,t>: s_<<e,t>,t>((λ x_e: o_<<e,t>,t>((λ y_e: love_<e,<e,t>>(x_e)(y_e)))))))'/<<<e,t>,t>,<<<e,t>,t>,t>> and '⟦[every man]⟧ = (λ m_<e,t>: (Forall x_e: (man_<e,t>(x_e) >> m_<e,t>(x_e))))'/<<e,t>,t> conflict (Predicate Modification), ⟦[love [every man]]⟧ = Composition failure (PA requires a valid binder) on: ⟦love⟧ = (λ o_<<e,t>,t>: (λ s_<<e,t>,t>: s_<<e,t>,t>((λ x_e: o_<<e,t>,t>((λ y_e: love_<e,<e,t>>(x_e)(y_e))))))) * ⟦[every man]⟧ = (λ m_<e,t>: (Forall x
# ...

# %%
qrsent
# Out:
# CompositionResult(results=[⟦[[QR [a woman]] [love [every man]]]⟧ = (Exists x_e: (woman_<e,t>(x_e) & (Forall x1_e: (man_<e,t>(x1_e) >> love_<e,<e,t>>(x_e)(x1_e)))))], failures=[⟦[[love [every man]] [QR [a woman]]]⟧ = Type mismatch: '⟦[love [every man]]⟧ = (λ s_<<e,t>,t>: s_<<e,t>,t>((λ x_e: (Forall x1_e: (man_<e,t>(x1_e) >> love_<e,<e,t>>(x_e)(x1_e))))))'/<<<e,t>,t>,t> and '⟦[QR [a woman]]⟧ = (λ p_<<<e,t>,t>,t>: (Exists x_e: (woman_<e,t>(x_e) & p_<<<e,t>,t>,t>((λ k_<e,t>: k_<e,t>(x_e))))))'/<<<<e,t>,t>,t>,t> conflict (Function Application), ⟦[[QR [a woman]] [love [every man]]]⟧ = Type mismatch: '⟦[QR [a woman]]⟧ = (λ p_<<<e,t>,t>,t>: (Exists x_e: (woman_<e,t>(x_e) & p_<<<e,t>,t>,t>((λ k_<e,t>: k_<e,t>(x_e))))))'/<<<<e,t>,t>,t>,t> and '⟦[love [every man]]⟧ = (λ s_<<e,t>,t>: s_<<e,t>,t>((λ x_e: (Forall x1_e: (man_<e,t>(x1_e) >> love_<e,<e,t>>(x_e)(x1_e))))))'/<<<e,t>,t>,t> conflict (Predicate Modification), ⟦[[QR [a woman]] [love [every man]]]⟧ = Composition failure (PA requires a valid
# ...

# %%
qrsent.tree()
# Out:
# 1 composition path:<br /><div align="center" style="display:table; margin:5px; border-collapse: collapse;border: 1px solid #848482;"><div align="center" style="display:table-row;border-bottom:1px solid #848482"><div style="display:table-cell;vertical-align:middle;"><div style="display: table;"><div style="display:table-cell;vertical-align:middle;padding-left:5px;padding-right:5px;padding-top:5px;padding-bottom:5px;"><div align="center" style="display:table; margin:5px; border-collapse: collapse;border: 1px solid #848482;"><div align="center" style="display:table-row;border-bottom:1px solid #848482"><div style="display:table-cell;vertical-align:middle;"><div style="display: table;"><div style="display:table-cell;vertical-align:middle;padding-left:5px;padding-right:5px;padding-top:5px;padding-bottom:5px;"><div align="center" style="display:block;padding-left:5px;padding-right:5px;padding-top:5px;padding-bottom:5px;"><div style="display:table;table-layout:auto;" align="center"><div styl
# ...

# %%
qrsent.trace()
# Out:
# Full composition trace.  1 path:<br />
# &nbsp;&nbsp;&nbsp;&nbsp;Step 1: $[\![\mathbf{\text{QR}}]\!]^{}_{\left\langle{}\left\langle{}\left\langle{}e,t\right\rangle{},t\right\rangle{},\left\langle{}\left\langle{}\left\langle{}\left\langle{}e,t\right\rangle{},t\right\rangle{},t\right\rangle{},t\right\rangle{}\right\rangle{}} \:=\: $$\lambda{} n_{\left\langle{}\left\langle{}e,t\right\rangle{},t\right\rangle{}} \: . \: \lambda{} p_{\left\langle{}\left\langle{}\left\langle{}e,t\right\rangle{},t\right\rangle{},t\right\rangle{}} \: . \: {n}(\lambda{} x_{e} \: . \: {p}(\lambda{} k_{\left\langle{}e,t\right\rangle{}} \: . \: {k}({x})))$<br />
# ...

# %% [markdown]
# ## SC 2019 exam
#
# 1. Compute the semantic representation of the sentence: "Every knight seeks a dragon", whose abstract syntax is given by the following term: `seek (a dragon) (every knight)`
# 2. Which reading do you obtain? Give a context that favors this reading.
# 3. Give two alternative semantic recipes for seek that lead to two other possible readings. Explain these two additional readings. Give contexts that favor them.
# 4. Is it possible to obtain an object-wide-scope de dicto reading? Explain why.

# %% [markdown]
# ### 2019 Q1
#
# Q1. Compute the semantic representation of the sentence: "Every knight seeks a dragon", whose abstract syntax is given by the following term: `seek (a dragon) (every knight)`

# %%
# %%lamb
# ||find|| = find_<e,<e,t>>
# ||Try|| = try_<e,<<e,t>,t>>
# # ^ these first two will not actually be used
#
# ||every|| = λ m_<e,t>: λ n_<e,t>: Forall x_e: (m(x) >> n(x))
# ||a|| = λ m_<e,t>: λ n_<e,t>: Exists x_e: (m(x) & n(x))
#
# # simple definition of 'seek'
# ||seek_simple|| = λ o_<<e,t>,t>: λ s_<<e,t>,t>: s(λ x_e: o(λ y_e: seek_<e,<e,t>>(x)(y)))
#
# # complex definition of 'seek', as given in 2019 exam
# ||seek_TF|| = λ o_<<e,t>,t>: λ s_<<e,t>,t>: s(λ x_e: o(  λ y_e: try_<e,<<e,t>,t>> (x) (λ z_e: find_<e,<e,t>>(z)(y))  ))
#
# ||knight|| = knight_<e,t>
# ||dragon|| = dragon_<e,t>
# Out:
# $[\![\mathbf{\text{find}}]\!]^{}_{\left\langle{}e,\left\langle{}e,t\right\rangle{}\right\rangle{}} \:=\: $${find}_{\left\langle{}e,\left\langle{}e,t\right\rangle{}\right\rangle{}}$<br />
# $[\![\mathbf{\text{Try}}]\!]^{}_{\left\langle{}e,\left\langle{}\left\langle{}e,t\right\rangle{},t\right\rangle{}\right\rangle{}} \:=\: $${try}_{\left\langle{}e,\left\langle{}\left\langle{}e,t\right\rangle{},t\right\rangle{}\right\rangle{}}$<br />
# $[\![\mathbf{\text{every}}]\!]^{}_{\left\langle{}\left\langle{}e,t\right\rangle{},\left\langle{}\left\langle{}e,t\right\rangle{},t\right\rangle{}\right\rangle{}} \:=\: $$\lambda{} m_{\left\langle{}e,t\right\rangle{}} \: . \: \lambda{} n_{\left\langle{}e,t\right\rangle{}} \: . \: \forall{} x_{e} \: . \: ({m}({x}) \rightarrow{} {n}({x}))$<br />
# ...

# %%
AD = a*dragon
EK = every*knight

S_simple_AD_EK = (seek_simple*AD)*EK
S_tf_AD_EK = (seek_TF*AD)*EK

# %%
AD.tree()
# Out:
# 1 composition path:<br /><div align="center" style="display:table; margin:5px; border-collapse: collapse;border: 1px solid #848482;"><div align="center" style="display:table-row;border-bottom:1px solid #848482"><div style="display:table-cell;vertical-align:middle;"><div style="display: table;"><div style="display:table-cell;vertical-align:middle;padding-left:5px;padding-right:5px;padding-top:5px;padding-bottom:5px;"><div align="center" style="display:block;padding-left:5px;padding-right:5px;padding-top:5px;padding-bottom:5px;"><div style="display:table;table-layout:auto;" align="center"><div style="display:table-row;"><div style="display:table-cell;padding-right:2px; padding-left:2px;" align="center"><div style="display:inline-block;"><span>$[\![\mathbf{\text{a}}]\!]^{}_{\left\langle{}\left\langle{}e,t\right\rangle{},\left\langle{}\left\langle{}e,t\right\rangle{},t\right\rangle{}\right\rangle{}}$</span></div></div></div><div style="display:table-row;"><div style="display:table-cell;p
# ...

# %%
EK.tree()
# Out:
# 1 composition path:<br /><div align="center" style="display:table; margin:5px; border-collapse: collapse;border: 1px solid #848482;"><div align="center" style="display:table-row;border-bottom:1px solid #848482"><div style="display:table-cell;vertical-align:middle;"><div style="display: table;"><div style="display:table-cell;vertical-align:middle;padding-left:5px;padding-right:5px;padding-top:5px;padding-bottom:5px;"><div align="center" style="display:block;padding-left:5px;padding-right:5px;padding-top:5px;padding-bottom:5px;"><div style="display:table;table-layout:auto;" align="center"><div style="display:table-row;"><div style="display:table-cell;padding-right:2px; padding-left:2px;" align="center"><div style="display:inline-block;"><span>$[\![\mathbf{\text{every}}]\!]^{}_{\left\langle{}\left\langle{}e,t\right\rangle{},\left\langle{}\left\langle{}e,t\right\rangle{},t\right\rangle{}\right\rangle{}}$</span></div></div></div><div style="display:table-row;"><div style="display:table-ce
# ...

# %%
S_simple_AD_EK.tree()
# Out:
# 1 composition path:<br /><div align="center" style="display:table; margin:5px; border-collapse: collapse;border: 1px solid #848482;"><div align="center" style="display:table-row;border-bottom:1px solid #848482"><div style="display:table-cell;vertical-align:middle;"><div style="display: table;"><div style="display:table-cell;vertical-align:middle;padding-left:5px;padding-right:5px;padding-top:5px;padding-bottom:5px;"><div align="center" style="display:table; margin:5px; border-collapse: collapse;border: 1px solid #848482;"><div align="center" style="display:table-row;border-bottom:1px solid #848482"><div style="display:table-cell;vertical-align:middle;"><div style="display: table;"><div style="display:table-cell;vertical-align:middle;padding-left:5px;padding-right:5px;padding-top:5px;padding-bottom:5px;"><div align="center" style="display:block;padding-left:5px;padding-right:5px;padding-top:5px;padding-bottom:5px;"><div style="display:table;table-layout:auto;" align="center"><div styl
# ...

# %%
S_tf_AD_EK.tree()
# Out:
# 1 composition path:<br /><div align="center" style="display:table; margin:5px; border-collapse: collapse;border: 1px solid #848482;"><div align="center" style="display:table-row;border-bottom:1px solid #848482"><div style="display:table-cell;vertical-align:middle;"><div style="display: table;"><div style="display:table-cell;vertical-align:middle;padding-left:5px;padding-right:5px;padding-top:5px;padding-bottom:5px;"><div align="center" style="display:table; margin:5px; border-collapse: collapse;border: 1px solid #848482;"><div align="center" style="display:table-row;border-bottom:1px solid #848482"><div style="display:table-cell;vertical-align:middle;"><div style="display: table;"><div style="display:table-cell;vertical-align:middle;padding-left:5px;padding-right:5px;padding-top:5px;padding-bottom:5px;"><div align="center" style="display:block;padding-left:5px;padding-right:5px;padding-top:5px;padding-bottom:5px;"><div style="display:table;table-layout:auto;" align="center"><div styl
# ...

# %%
S_simple_AD_EK.trace()
# Out:
# Full composition trace.  1 path:<br />
# &nbsp;&nbsp;&nbsp;&nbsp;Step 1: $[\![\mathbf{\text{seek_simple}}]\!]^{}_{\left\langle{}\left\langle{}\left\langle{}e,t\right\rangle{},t\right\rangle{},\left\langle{}\left\langle{}\left\langle{}e,t\right\rangle{},t\right\rangle{},t\right\rangle{}\right\rangle{}} \:=\: $$\lambda{} o_{\left\langle{}\left\langle{}e,t\right\rangle{},t\right\rangle{}} \: . \: \lambda{} s_{\left\langle{}\left\langle{}e,t\right\rangle{},t\right\rangle{}} \: . \: {s}(\lambda{} x_{e} \: . \: {o}(\lambda{} y_{e} \: . \: {seek}_{\left\langle{}e,\left\langle{}e,t\right\rangle{}\right\rangle{}}({x})({y})))$<br />
# ...

# %%
S_tf_AD_EK.trace()
# Out:
# Full composition trace.  1 path:<br />
# &nbsp;&nbsp;&nbsp;&nbsp;Step 1: $[\![\mathbf{\text{seek_TF}}]\!]^{}_{\left\langle{}\left\langle{}\left\langle{}e,t\right\rangle{},t\right\rangle{},\left\langle{}\left\langle{}\left\langle{}e,t\right\rangle{},t\right\rangle{},t\right\rangle{}\right\rangle{}} \:=\: $$\lambda{} o_{\left\langle{}\left\langle{}e,t\right\rangle{},t\right\rangle{}} \: . \: \lambda{} s_{\left\langle{}\left\langle{}e,t\right\rangle{},t\right\rangle{}} \: . \: {s}(\lambda{} x_{e} \: . \: {o}(\lambda{} y_{e} \: . \: {try}_{\left\langle{}e,\left\langle{}\left\langle{}e,t\right\rangle{},t\right\rangle{}\right\rangle{}}({x})(\lambda{} z_{e} \: . \: {find}_{\left\langle{}e,\left\langle{}e,t\right\rangle{}\right\rangle{}}({z})({y}))))$<br />
# ...

# %% [markdown]
# It seems weird to have the `λz` hanging around unsatisfied after we are done,
# but that is how it was when I did it on paper,
# and that is also how it is when the computer calculates it.

# %% [markdown]
# ### 2019 Q2
#
# Q2. Which reading do you obtain? Give a context that favors this reading.
#
# We obtain the de dicto (de dicto: "what is said") reading.
# Note that Forall quantifier has higher scope than Exists quantifier. Thus we are not talking about one specific something.
#
# *Note: To be talking about one specific something (de re: "a thing"), we would need Existential quantifier to be higher scope.*
#
# As for context to favor this de dicto reading, in my opinion this is the more obvious reading.
# A valid context might be something like... there are a lot of knights and they are all looking for their own dragon so they can get famous for finding (killing?) a new one.
#
# ### 2019 Q3
#
# Q3:
# Give two alternative semantic recipes for seek that lead to two other possible readings. Explain these two additional readings. Give contexts that favor them.

# %%
'''First, lets try just switching up the order of arguments for seek, 
without changing the definition from before.'''
sent = (seek_TF*(EK))*AD
sent.tree()
# Out:
# 1 composition path:<br /><div align="center" style="display:table; margin:5px; border-collapse: collapse;border: 1px solid #848482;"><div align="center" style="display:table-row;border-bottom:1px solid #848482"><div style="display:table-cell;vertical-align:middle;"><div style="display: table;"><div style="display:table-cell;vertical-align:middle;padding-left:5px;padding-right:5px;padding-top:5px;padding-bottom:5px;"><div align="center" style="display:table; margin:5px; border-collapse: collapse;border: 1px solid #848482;"><div align="center" style="display:table-row;border-bottom:1px solid #848482"><div style="display:table-cell;vertical-align:middle;"><div style="display: table;"><div style="display:table-cell;vertical-align:middle;padding-left:5px;padding-right:5px;padding-top:5px;padding-bottom:5px;"><div align="center" style="display:block;padding-left:5px;padding-right:5px;padding-top:5px;padding-bottom:5px;"><div style="display:table;table-layout:auto;" align="center"><div styl
# ...

# %% [markdown]
# In the output from this, we see that the Exists quantifier is higher in scope now.
# So we now have a single dragon.
# However, this sentence means "There is a dragon that seeks every knight."
# (Since we switch the order of arguments without changing definition of 'seeks'.)
#
# Based on this, it seems that by simply swapping the order that 'seek' expects its obj/subj args,
# we could have Exists quantifier higher in scope.
#
# Note that we want to have a reading with both:
# (1) Exists quantifier high in scope, and
# (2) correct obj/subj for "seeks(knight,dragon)"
#
# Assuming we want to keep the application order `seek (a dragon) (every knight)` (since that's what we were told is the proper order, in the exam instructions), we will not change the order of o/s in the lambda bindings.
# Instead, we will change the order of o/s inside the interior of the definition.

# %%
# %%lamb
# # definition of 'seek' with s and o swapped
# ||seek_TF_so1|| = λ o_<<e,t>,t>: λ s_<<e,t>,t>: o(λ x_e: s(  λ y_e: try_<e,<<e,t>,t>> (x) (λ z_e: find_<e,<e,t>>(z)(y))  ))
# Out:
# $[\![\mathbf{\text{seek_TF_so1}}]\!]^{}_{\left\langle{}\left\langle{}\left\langle{}e,t\right\rangle{},t\right\rangle{},\left\langle{}\left\langle{}\left\langle{}e,t\right\rangle{},t\right\rangle{},t\right\rangle{}\right\rangle{}} \:=\: $$\lambda{} o_{\left\langle{}\left\langle{}e,t\right\rangle{},t\right\rangle{}} \: . \: \lambda{} s_{\left\langle{}\left\langle{}e,t\right\rangle{},t\right\rangle{}} \: . \: {o}(\lambda{} x_{e} \: . \: {s}(\lambda{} y_{e} \: . \: {try}_{\left\langle{}e,\left\langle{}\left\langle{}e,t\right\rangle{},t\right\rangle{}\right\rangle{}}({x})(\lambda{} z_{e} \: . \: {find}_{\left\langle{}e,\left\langle{}e,t\right\rangle{}\right\rangle{}}({z})({y}))))$

# %%
# original complex definition of 'seek', as given in 2019 exam.
# Exactly same as before, just repeated here for reference.
seek_TF
# Out:
# ⟦seek_TF⟧ = (λ o_<<e,t>,t>: (λ s_<<e,t>,t>: s_<<e,t>,t>((λ x_e: o_<<e,t>,t>((λ y_e: try_<e,<<e,t>,t>>(x_e)((λ z_e: find_<e,<e,t>>(z_e)(y_e)))))))))

# %%
'''The output of this is almost right, but, it means "There's a dragon that seeks every knight",
which is not what we want.'''
sent = (seek_TF_so1*(AD))*EK
sent.tree()
# Out:
# 1 composition path:<br /><div align="center" style="display:table; margin:5px; border-collapse: collapse;border: 1px solid #848482;"><div align="center" style="display:table-row;border-bottom:1px solid #848482"><div style="display:table-cell;vertical-align:middle;"><div style="display: table;"><div style="display:table-cell;vertical-align:middle;padding-left:5px;padding-right:5px;padding-top:5px;padding-bottom:5px;"><div align="center" style="display:table; margin:5px; border-collapse: collapse;border: 1px solid #848482;"><div align="center" style="display:table-row;border-bottom:1px solid #848482"><div style="display:table-cell;vertical-align:middle;"><div style="display: table;"><div style="display:table-cell;vertical-align:middle;padding-left:5px;padding-right:5px;padding-top:5px;padding-bottom:5px;"><div align="center" style="display:block;padding-left:5px;padding-right:5px;padding-top:5px;padding-bottom:5px;"><div style="display:table;table-layout:auto;" align="center"><div styl
# ...

# %% [markdown]
# We need the x in dragon(x) and the x in the first arg of try(x)(...) to NOT be the same.
# Let's try also swapping the lambda bindings for x and y in the definition.

# %%
# %%lamb
# # definition of 'seek' with s and o swapped AND the lambda y and x swapped
# ||seek_TF_so2|| = λ o_<<e,t>,t>: λ s_<<e,t>,t>: o(λ y_e: s(  λ x_e: try_<e,<<e,t>,t>> (x) (λ z_e: find_<e,<e,t>>(z)(y))  ))
# Out:
# $[\![\mathbf{\text{seek_TF_so2}}]\!]^{}_{\left\langle{}\left\langle{}\left\langle{}e,t\right\rangle{},t\right\rangle{},\left\langle{}\left\langle{}\left\langle{}e,t\right\rangle{},t\right\rangle{},t\right\rangle{}\right\rangle{}} \:=\: $$\lambda{} o_{\left\langle{}\left\langle{}e,t\right\rangle{},t\right\rangle{}} \: . \: \lambda{} s_{\left\langle{}\left\langle{}e,t\right\rangle{},t\right\rangle{}} \: . \: {o}(\lambda{} y_{e} \: . \: {s}(\lambda{} x_{e} \: . \: {try}_{\left\langle{}e,\left\langle{}\left\langle{}e,t\right\rangle{},t\right\rangle{}\right\rangle{}}({x})(\lambda{} z_{e} \: . \: {find}_{\left\langle{}e,\left\langle{}e,t\right\rangle{}\right\rangle{}}({z})({y}))))$

# %%
seek_TF # the original again for reference
# Out:
# ⟦seek_TF⟧ = (λ o_<<e,t>,t>: (λ s_<<e,t>,t>: s_<<e,t>,t>((λ x_e: o_<<e,t>,t>((λ y_e: try_<e,<<e,t>,t>>(x_e)((λ z_e: find_<e,<e,t>>(z_e)(y_e)))))))))

# %%
'''The output of this is what we want. '''
sent = (seek_TF_so2*(AD))*EK
sent.tree()
# Out:
# 1 composition path:<br /><div align="center" style="display:table; margin:5px; border-collapse: collapse;border: 1px solid #848482;"><div align="center" style="display:table-row;border-bottom:1px solid #848482"><div style="display:table-cell;vertical-align:middle;"><div style="display: table;"><div style="display:table-cell;vertical-align:middle;padding-left:5px;padding-right:5px;padding-top:5px;padding-bottom:5px;"><div align="center" style="display:table; margin:5px; border-collapse: collapse;border: 1px solid #848482;"><div align="center" style="display:table-row;border-bottom:1px solid #848482"><div style="display:table-cell;vertical-align:middle;"><div style="display: table;"><div style="display:table-cell;vertical-align:middle;padding-left:5px;padding-right:5px;padding-top:5px;padding-bottom:5px;"><div align="center" style="display:block;padding-left:5px;padding-right:5px;padding-top:5px;padding-bottom:5px;"><div style="display:table;table-layout:auto;" align="center"><div styl
# ...

# %% [markdown]
# The exam asks for two alternative defs... this is just one.

# %% [markdown]
# ## Etc notes
#
# https://en.wikipedia.org/wiki/De_dicto_and_de_re
#
# https://en.wikipedia.org/wiki/Operator_(linguistics)#Quantifier_raising
#
# https://en.wikipedia.org/wiki/Scope_(formal_semantics)
#
# https://en.wikipedia.org/wiki/Generalized_quantifier

# %% [markdown]
# ## 2021 exam
#
# 1. Compute the semantic representation of the sentence Alice believes that
# someone left, the abstract syntax of which is given by the following term:
# `believe (that (left someone)) alice`
#
# 2. Assume that:
#
# `qr someone →β→ λp. ∃x. (human x) ∧ (p (λk. k x))`
#
# Compute another semantic representation of the sentence Alice believes that
# someone left, the alternative abstract syntax of which is given by the following term:
#
# `qr someone (λs. believe (that (left s)) alice)`
#
# 3. Assign an appropriate semantic interpretation to qr such that:
# `qr someone →β→ λp. ∃x. (human x) ∧ (p (λk. k x))`
#
# 4. Discuss the difference between the two interpretations you have obtained for the sentence
# "Alice believes that someone left".

# %%
# %%lamb
# ||NP|| = NP_<<e,t>,t>
# ||S|| = S_t
# ||CC|| = CC_t
#
# ||a|| = a_e
# ||human|| = human_<e,t>
# ||left|| = left_<e,t>
# ||B|| = B_<e,<t,t>>
# # ^ we will not actually use these
# Out:
# $[\![\mathbf{\text{NP}}]\!]^{}_{\left\langle{}\left\langle{}e,t\right\rangle{},t\right\rangle{}} \:=\: $${NP}_{\left\langle{}\left\langle{}e,t\right\rangle{},t\right\rangle{}}$<br />
# $[\![\mathbf{\text{S}}]\!]^{}_{t} \:=\: $${S}_{t}$<br />
# $[\![\mathbf{\text{CC}}]\!]^{}_{t} \:=\: $${CC}_{t}$<br />
# $[\![\mathbf{\text{a}}]\!]^{}_{e} \:=\: $${a}_{e}$<br />
# $[\![\mathbf{\text{human}}]\!]^{}_{\left\langle{}e,t\right\rangle{}} \:=\: $${human}_{\left\langle{}e,t\right\rangle{}}$<br />
# $[\![\mathbf{\text{left}}]\!]^{}_{\left\langle{}e,t\right\rangle{}} \:=\: $${left}_{\left\langle{}e,t\right\rangle{}}$<br />
# $[\![\mathbf{\text{B}}]\!]^{}_{\left\langle{}e,\left\langle{}t,t\right\rangle{}\right\rangle{}} \:=\: $${B}_{\left\langle{}e,\left\langle{}t,t\right\rangle{}\right\rangle{}}$

# %%
# %%lamb
# ||alice|| = λ k_<e,t>: k(a)
# ||someone|| = λ k_<e,t>: Exists x_e: (human_<e,t>(x) & k(x))
#
# ||left|| = L s_<<e,t>,t>: s( L x_e: left_<e,t>(x) )
#
# # TODO fix the type annotations on believe
# ||believe|| = L c_t: L s_<<e,t>,t>: s( L x_e: B_<e,<t,t>> (x)(c) )
#
# ||that|| = L x_t : x
# Out:
# $[\![\mathbf{\text{alice}}]\!]^{}_{\left\langle{}\left\langle{}e,t\right\rangle{},t\right\rangle{}} \:=\: $$\lambda{} k_{\left\langle{}e,t\right\rangle{}} \: . \: {k}({a}_{e})$<br />
# $[\![\mathbf{\text{someone}}]\!]^{}_{\left\langle{}\left\langle{}e,t\right\rangle{},t\right\rangle{}} \:=\: $$\lambda{} k_{\left\langle{}e,t\right\rangle{}} \: . \: \exists{} x_{e} \: . \: ({human}_{\left\langle{}e,t\right\rangle{}}({x}) \wedge{} {k}({x}))$<br />
# $[\![\mathbf{\text{left}}]\!]^{}_{\left\langle{}\left\langle{}\left\langle{}e,t\right\rangle{},t\right\rangle{},t\right\rangle{}} \:=\: $$\lambda{} s_{\left\langle{}\left\langle{}e,t\right\rangle{},t\right\rangle{}} \: . \: {s}(\lambda{} x_{e} \: . \: {left}_{\left\langle{}e,t\right\rangle{}}({x}))$<br />
# ...

# %% [markdown]
# ### Q1
#
# Q1. Compute the semantic representation of the sentence Alice believes that
# someone left, the abstract syntax of which is given by the following term:
# `believe (that (left someone)) alice`

# %%
sent = ( believe * (that*(left*somebody)) ) * alice
sent.tree()
# Out:
# 1 composition path:<br /><div align="center" style="display:table; margin:5px; border-collapse: collapse;border: 1px solid #848482;"><div align="center" style="display:table-row;border-bottom:1px solid #848482"><div style="display:table-cell;vertical-align:middle;"><div style="display: table;"><div style="display:table-cell;vertical-align:middle;padding-left:5px;padding-right:5px;padding-top:5px;padding-bottom:5px;"><div align="center" style="display:table; margin:5px; border-collapse: collapse;border: 1px solid #848482;"><div align="center" style="display:table-row;border-bottom:1px solid #848482"><div style="display:table-cell;vertical-align:middle;"><div style="display: table;"><div style="display:table-cell;vertical-align:middle;padding-left:5px;padding-right:5px;padding-top:5px;padding-bottom:5px;"><div align="center" style="display:block;padding-left:5px;padding-right:5px;padding-top:5px;padding-bottom:5px;"><div style="display:table;table-layout:auto;" align="center"><div styl
# ...

# %%
LS = left*someone
LS.tree()
# Out:
# 1 composition path:<br /><div align="center" style="display:table; margin:5px; border-collapse: collapse;border: 1px solid #848482;"><div align="center" style="display:table-row;border-bottom:1px solid #848482"><div style="display:table-cell;vertical-align:middle;"><div style="display: table;"><div style="display:table-cell;vertical-align:middle;padding-left:5px;padding-right:5px;padding-top:5px;padding-bottom:5px;"><div align="center" style="display:block;padding-left:5px;padding-right:5px;padding-top:5px;padding-bottom:5px;"><div style="display:table;table-layout:auto;" align="center"><div style="display:table-row;"><div style="display:table-cell;padding-right:2px; padding-left:2px;" align="center"><div style="display:inline-block;"><span>$[\![\mathbf{\text{left}}]\!]^{}_{\left\langle{}\left\langle{}\left\langle{}e,t\right\rangle{},t\right\rangle{},t\right\rangle{}}$</span></div></div></div><div style="display:table-row;"><div style="display:table-cell;padding-right:2px; padding-le
# ...

# %%
TLS = that*(left*someone)
TLS.tree()
# Out:
# 1 composition path:<br /><div align="center" style="display:table; margin:5px; border-collapse: collapse;border: 1px solid #848482;"><div align="center" style="display:table-row;border-bottom:1px solid #848482"><div style="display:table-cell;vertical-align:middle;"><div style="display: table;"><div style="display:table-cell;vertical-align:middle;padding-left:5px;padding-right:5px;padding-top:5px;padding-bottom:5px;"><div align="center" style="display:block;padding-left:5px;padding-right:5px;padding-top:5px;padding-bottom:5px;"><div style="display:table;table-layout:auto;" align="center"><div style="display:table-row;"><div style="display:table-cell;padding-right:2px; padding-left:2px;" align="center"><div style="display:inline-block;"><span>$[\![\mathbf{\text{that}}]\!]^{}_{\left\langle{}t,t\right\rangle{}}$</span></div></div></div><div style="display:table-row;"><div style="display:table-cell;padding-right:2px; padding-left:2px;" align="center"><div style="display:inline-block;"><sp
# ...

# %%
BTLS = believe*TLS
BTLS.tree()
# Out:
# 1 composition path:<br /><div align="center" style="display:table; margin:5px; border-collapse: collapse;border: 1px solid #848482;"><div align="center" style="display:table-row;border-bottom:1px solid #848482"><div style="display:table-cell;vertical-align:middle;"><div style="display: table;"><div style="display:table-cell;vertical-align:middle;padding-left:5px;padding-right:5px;padding-top:5px;padding-bottom:5px;"><div align="center" style="display:block;padding-left:5px;padding-right:5px;padding-top:5px;padding-bottom:5px;"><div style="display:table;table-layout:auto;" align="center"><div style="display:table-row;"><div style="display:table-cell;padding-right:2px; padding-left:2px;" align="center"><div style="display:inline-block;"><span>$[\![\mathbf{\text{believe}}]\!]^{}_{\left\langle{}t,\left\langle{}\left\langle{}\left\langle{}e,t\right\rangle{},t\right\rangle{},t\right\rangle{}\right\rangle{}}$</span></div></div></div><div style="display:table-row;"><div style="display:table-
# ...

# %%
BTLSA = BTLS*alice
BTLSA.tree()
# Out:
# 1 composition path:<br /><div align="center" style="display:table; margin:5px; border-collapse: collapse;border: 1px solid #848482;"><div align="center" style="display:table-row;border-bottom:1px solid #848482"><div style="display:table-cell;vertical-align:middle;"><div style="display: table;"><div style="display:table-cell;vertical-align:middle;padding-left:5px;padding-right:5px;padding-top:5px;padding-bottom:5px;"><div align="center" style="display:table; margin:5px; border-collapse: collapse;border: 1px solid #848482;"><div align="center" style="display:table-row;border-bottom:1px solid #848482"><div style="display:table-cell;vertical-align:middle;"><div style="display: table;"><div style="display:table-cell;vertical-align:middle;padding-left:5px;padding-right:5px;padding-top:5px;padding-bottom:5px;"><div align="center" style="display:block;padding-left:5px;padding-right:5px;padding-top:5px;padding-bottom:5px;"><div style="display:table;table-layout:auto;" align="center"><div styl
# ...

# %% [markdown]
# ### Q2 (2021 exam)
#
# Q2. Assume that:
#
# `qr someone →β→ λp. ∃x. (human x) ∧ (p (λk. k x))`
#
# Compute another semantic representation of the sentence Alice believes that
# someone left, the alternative abstract syntax of which is given by the following term:
#
# `qr someone (λs. believe (that (left s)) alice)`

# %%
# TODO

# %% [markdown]
# ### Q3
#
# Q3. Assign an appropriate semantic interpretation to `qr` such that:
# `qr someone →β→ λp. ∃x. (human x) ∧ (p (λk. k x))`

# %%
# %%lamb
# # repeat of the definitions we were given
# ||someone|| = λ k_<e,t>: Exists x_e: (human_<e,t>(x) & k(x))
#
# ||qr_someone|| = L p_<<<e,t>,t>,t>: Exists x_e: human_<e,t>(x) & p( L k_<e,t>: k(x) )
# Out:
# $[\![\mathbf{\text{someone}}]\!]^{}_{\left\langle{}\left\langle{}e,t\right\rangle{},t\right\rangle{}} \:=\: $$\lambda{} k_{\left\langle{}e,t\right\rangle{}} \: . \: \exists{} x_{e} \: . \: ({human}_{\left\langle{}e,t\right\rangle{}}({x}) \wedge{} {k}({x}))$<br />
# $[\![\mathbf{\text{qr_someone}}]\!]^{}_{\left\langle{}\left\langle{}\left\langle{}\left\langle{}e,t\right\rangle{},t\right\rangle{},t\right\rangle{},t\right\rangle{}} \:=\: $$\lambda{} p_{\left\langle{}\left\langle{}\left\langle{}e,t\right\rangle{},t\right\rangle{},t\right\rangle{}} \: . \: \exists{} x_{e} \: . \: ({human}_{\left\langle{}e,t\right\rangle{}}({x}) \wedge{} {p}(\lambda{} k_{\left\langle{}e,t\right\rangle{}} \: . \: {k}({x})))$

# %%
# %%lamb
# # new definition, for QR
# ||QR|| = L n_<<e,t>,t>: L p_<<<e,t>,t>,t>:  n( L x_e: p(L k_<e,t>: k(x)) )
# Out:
# $[\![\mathbf{\text{QR}}]\!]^{}_{\left\langle{}\left\langle{}\left\langle{}e,t\right\rangle{},t\right\rangle{},\left\langle{}\left\langle{}\left\langle{}\left\langle{}e,t\right\rangle{},t\right\rangle{},t\right\rangle{},t\right\rangle{}\right\rangle{}} \:=\: $$\lambda{} n_{\left\langle{}\left\langle{}e,t\right\rangle{},t\right\rangle{}} \: . \: \lambda{} p_{\left\langle{}\left\langle{}\left\langle{}e,t\right\rangle{},t\right\rangle{},t\right\rangle{}} \: . \: {n}(\lambda{} x_{e} \: . \: {p}(\lambda{} k_{\left\langle{}e,t\right\rangle{}} \: . \: {k}({x})))$

# %%
(QR*someone).tree()
# Out:
# 1 composition path:<br /><div align="center" style="display:table; margin:5px; border-collapse: collapse;border: 1px solid #848482;"><div align="center" style="display:table-row;border-bottom:1px solid #848482"><div style="display:table-cell;vertical-align:middle;"><div style="display: table;"><div style="display:table-cell;vertical-align:middle;padding-left:5px;padding-right:5px;padding-top:5px;padding-bottom:5px;"><div align="center" style="display:block;padding-left:5px;padding-right:5px;padding-top:5px;padding-bottom:5px;"><div style="display:table;table-layout:auto;" align="center"><div style="display:table-row;"><div style="display:table-cell;padding-right:2px; padding-left:2px;" align="center"><div style="display:inline-block;"><span>$[\![\mathbf{\text{QR}}]\!]^{}_{\left\langle{}\left\langle{}\left\langle{}e,t\right\rangle{},t\right\rangle{},\left\langle{}\left\langle{}\left\langle{}\left\langle{}e,t\right\rangle{},t\right\rangle{},t\right\rangle{},t\right\rangle{}\right\rangl
# ...

# %%
((believe * (that*(left*someone))) * alice) .tree()
# Out:
# 1 composition path:<br /><div align="center" style="display:table; margin:5px; border-collapse: collapse;border: 1px solid #848482;"><div align="center" style="display:table-row;border-bottom:1px solid #848482"><div style="display:table-cell;vertical-align:middle;"><div style="display: table;"><div style="display:table-cell;vertical-align:middle;padding-left:5px;padding-right:5px;padding-top:5px;padding-bottom:5px;"><div align="center" style="display:table; margin:5px; border-collapse: collapse;border: 1px solid #848482;"><div align="center" style="display:table-row;border-bottom:1px solid #848482"><div style="display:table-cell;vertical-align:middle;"><div style="display: table;"><div style="display:table-cell;vertical-align:middle;padding-left:5px;padding-right:5px;padding-top:5px;padding-bottom:5px;"><div align="center" style="display:block;padding-left:5px;padding-right:5px;padding-top:5px;padding-bottom:5px;"><div style="display:table;table-layout:auto;" align="center"><div styl
# ...

# %% [markdown]
# The basic steps for doing Q3 on paper:
#
# - Look at the type annotations and other info given in the exam, and see that QR is a function that takes two arguments. Start writing a lambda expression with two args: `||QR|| = L u : L v : (...)`
# - We know that the lambda expression will need a head, which is likely to be one of the two those variables u or v.   So it could be:
#     ` ||QR|| = L u : L v : u(...) ` ...or...
#     ` ||QR|| = L u : L v : v(...) `
#   Just guess one and go with it, if it doesnt work try the other one. (Hint from the future: you want u not v.)
#
# - So, let's try moving forward with this guess: ` ||QR|| = L u : L v : u( blarg ) `
#   We put a placeholder named `blarg` in there for the stuff we dont know yet.
#
# - Now, take your partial definition and do the function application (QR * SOMEONE).
# - Once you reduce everything, take your result (QR_SOMEONE_HYPOTHESIS) and compare it character-for-character with the lambda expression for QR_SOMEONE_OFFICIAL given in the exam instructions.
#
# - Notice that they match almost exactly for the first part, but yours has ` blarg(x) ` where the original has ` p( L k . k(x) ) `
# - Take those two subparts and set them equal to each other. ` [ blarg(x) ] == [ p(L k. k(x)) ] `
# - Now, we know that blarg must be defined as a function that takes an x, and sends us back [ p(L k. k(x)) ]
# - Blarg wants an argument x, so start with `||blarg|| = Lx. (...)`
# - Not really sure what to do next, so just plug in the missing part from the other side of the equation, to make: ` ||blarg|| = Lx. [ p(L k. k(x)) ] `
# - Now you have a definition for `blarg`. Take it plug it back into your idea for a `QR` definition from the start: ` ||QR|| = L u : L v : u( Lx. [ p(L k. k(x)) ] ) `
# - Now we have a hypothesis definition for `QR`. But there's a problem. The 'p' hasn't been properly introduced.
#
# - How to solve? Since we know QR has only 2 args (not 3), we don't want to introduce another lambda at top-level. (And in any case, we already finalized that part of the QR definition.)
#     - Instead, perhaps we can introduce another lambda alongside Lx?
#     - OR, we can notice that our declared variable Lv is not being used. Could p == v? We can try it and see if it works.
#
# - Rename the p to v, and now we have a fully sketched hypothesis definition expression for QR.
# - Now let's try using it... try the functional application (QR * SOMEONE).
# - Once done reducing it, compare result with the official QR_SOMEONE_OFFICIAL given in the exam instructions. Does it match? Yes! So our definition of QR is right.

# %% [markdown]
# ### Q4
#
# Q4. Discuss the difference between the two interpretations you have obtained for the sentence
# "Alice believes that someone left".

# %%
# TODO
